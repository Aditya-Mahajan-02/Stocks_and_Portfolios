# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/Comprehensive_Banking_Database.csv")

# %%
df.head()
df['Customer ID'].tail()
# Out:
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: Customer ID, dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'First Name', 'Last Name', 'Age', 'Gender', 'Address',
#        'City', 'Contact Number', 'Email', 'Account Type', 'Account Balance',
#        'Date Of Account Opening', 'Last Transaction Date', 'TransactionID',
#        'Transaction Date', 'Transaction Type', 'Transaction Amount',
#        'Account Balance After Transaction', 'Branch ID', 'Loan ID',
#        'Loan Amount', 'Loan Type', 'Interest Rate', 'Loan Term',
#        'Approval/Rejection Date', 'Loan Status', 'CardID', 'Card Type',
#        'Credit Limit', 'Credit Card Balance', 'Minimum Payment Due',
#        'Payment Due Date', 'Last Credit Card Payment Date', 'Rewards Points',
#        'Feedback ID', 'Feedback Date', 'Feedback Type', 'Resolution Status',
#        'Resolution Date', 'Anomaly'],
#       dtype='object')

# %%
df.shape
# Out:
# (5000, 40)

# %%
newdf = df[[ 'Age', 'City',  'Account Balance', 'Gender']]
newdf.index = df['Customer ID']
newdf.head()
# Out:
#              Age           City  Account Balance  Gender
# Customer ID
# 1             45     Fort Worth          1313.38    Male
# 2             47     Louisville          5988.46  Female
# 3             25   Philadelphia          8277.88  Female
# 4             52  Oklahoma City          7487.21   Other
# 5             68        Phoenix          6993.55   Other

# %%
len(newdf['City'].unique())
# Out:
# 40

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(data = over50, x = 'Age', y = 'Account Balance' , hue='City')
plt.legend(bbox_to_anchor = (1.05,1), loc = "upper left")

# %%
over50 = newdf[newdf['Age'] > 50]
cinc = newdf[newdf['City'] == 'Dallas']

# %%
over50.head()
# Out:
#              Age           City  Account Balance Gender
# Customer ID
# 4             52  Oklahoma City          7487.21  Other
# 5             68        Phoenix          6993.55  Other
# 6             52        El Paso          9295.64   Male
# 9             52   Indianapolis          1109.30   Male
# 10            55     Washington          9554.62  Other

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(data = cinc, x = 'Age', y = 'Account Balance' , hue='City')
plt.legend(bbox_to_anchor = (1.05,1), loc = "upper left")
